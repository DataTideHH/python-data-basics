# %% [markdown]
# # Python data environment check
#
# This notebook verifies the project interpreter and direct runtime dependencies. Outputs are intentionally cleared before commit.

# %%
import matplotlib
import numpy as np
import pandas as pd

{
    "pandas": pd.__version__,
    "numpy": np.__version__,
    "matplotlib": matplotlib.__version__,
}
