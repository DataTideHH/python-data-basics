# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import sklearn

print("Executable:", sys.executable)
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("matplotlib:", matplotlib.__version__)
print("scikit-learn:", sklearn.__version__)
# Out:
# Executable: /Users/tobiaswietelmann/Code/python-data-basics/.venv/bin/python
# pandas: 3.0.3
# numpy: 2.4.6
# matplotlib: 3.10.9
# scikit-learn: 1.8.0
